# %%
# !pip install gradio
# !pip install transformers
# !pip install torch
# !pip install sentencepiece  # Often needed for tokenizers
# !pip install tokenizers  # Add this line to install the tokenizers package
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.8 MB/s eta 0:00:002.8 MB/s eta 0:00:01
# ...

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
import torch 
from sklearn.metrics import precision_score
from sklearn.linear_model import LogisticRegression as lr 
from sklearn.model_selection import train_test_split
import pandas as pd 
import numpy as np 
from tqdm import tqdm
import joblib
tqdm.pandas()

# %%
df = pd.read_csv('rew.csv')
df
# Out:
#                                                      des  pos  neg  score
# 0         خرید خوبی بود، ماندگاری بالا آن قابل توجه بود.    1    0      1
# 1      تجربه بدی بود، از باتری ضعیف آن ناراضی بودم. و...    0    2      0
# 2            در کل راضی بودم، نقطه قوتش طرح زیبا آن است.    1    0      1
# 3      محصول با کیفیتی است، پوشش دهی خوب آن قابل توجه...    1    0      1
# 4      محصول بی کیفیتی است، ترجمه ضعیف بدی داشت.از کی...    0    3      0
# ...                                                  ...  ...  ...    ...
# 11995  محصول بی کیفیتی است، از قیمت بسیار بالا آن نار...    0    1      0
# 11996  پیشنهاد میکنم، نقطه قوتش نصب آسان آن است. همچن...    2    0      1
# 11997  در کل راضی بودم، صفحه نمایش باکیفیت آن قابل تو...    1    0      1
# 11998  اصلا راضی نبودم، بوی نامطبوع آن مشکل اصلی بود....    0    2      0
# 11999  محصول بی کیفیتی است، نقطه ضعفش مصرف برق بالا آ...    0    1      0
#
# [12000 rows x 4 columns]

# %%
sen = pipeline('sentiment-analysis',model='HooshvareLab/bert-fa-base-uncased-sentiment-snappfood')
sen('بد')
# Out:
# Device set to use cpu
# [{'label': 'SAD', 'score': 0.9872704744338989}]

# %%
df["des"] = df["des"].apply(lambda x: 1 if sen(x)[0]["label"] == "HAPPY" else 0)

# %%
df
# Out:
#        des  pos  neg  score
# 0        1    1    0      1
# 1        0    0    2      0
# 2        1    1    0      1
# 3        1    1    0      1
# 4        0    0    3      0
# ...    ...  ...  ...    ...
# 11995    0    0    1      0
# 11996    1    2    0      1
# 11997    1    1    0      1
# 11998    0    0    2      0
# 11999    0    0    1      0
#
# [12000 rows x 4 columns]

# %%
x = df[['des','pos','neg']]
y = df['score']

# %%
x
# Out:
#        des  pos  neg
# 0        1    1    0
# 1        0    0    2
# 2        1    1    0
# 3        1    1    0
# 4        0    0    3
# ...    ...  ...  ...
# 11995    0    0    1
# 11996    1    2    0
# 11997    1    1    0
# 11998    0    0    2
# 11999    0    0    1
#
# [12000 rows x 3 columns]

# %%
y
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 11995    0
# 11996    1
# 11997    1
# 11998    0
# 11999    0
# Name: score, Length: 12000, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.4)

# %%
model = lr()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
yhat=model.predict(x_test)

# %%
precision_score(y_test, yhat)
# Out:
# 0.9779735682819384

# %%
joblib.dump(model,'mymodel')
# Out:
# ['mymodel']
